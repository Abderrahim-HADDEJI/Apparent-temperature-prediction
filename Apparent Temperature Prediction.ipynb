# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime as dt

# %%
df = pd.read_csv("weather_data1.csv")
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222  \
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)
# 0                  7.388889      0.89            14.1197  \
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)
# 0                     251          15.8263           0               1015.13  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5999 entries, 0 to 5998
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            5999 non-null   object
#  1   Summary                   5999 non-null   object
#  2   Precip Type               5999 non-null   object
#  3   Temperature (C)           5999 non-null   float64
#  4   Apparent Temperature (C)  5999 non-null   float64
#  5   Humidity                  5999 non-null   float64
#  6   Wind Speed (km/h)         5999 non-null   float64
#  7   Wind Bearing (degrees)    5999 non-null   int64
#  8   Visibility (km)           5999 non-null   float64
#  9   Loud Cover                5999 non-null   int64
#  10  Pressure (millibars)      5999 non-null   float64
#  11  Daily Summary             5999 non-null   object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 562.5+ KB

# %%
df.describe(include='all')
# Out:
#                        Formatted Date        Summary Precip Type
# count                            5999           5999        5999  \
# unique                           5999             14           2
# top     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# freq                                1           1791        4762
# mean                              NaN            NaN         NaN
# std                               NaN            NaN         NaN
# min                               NaN            NaN         NaN
# 25%                               NaN            NaN         NaN
# 50%                               NaN            NaN         NaN
# 75%                               NaN            NaN         NaN
# max                               NaN            NaN         NaN
#
#         Temperature (C)  Apparent Temperature (C)     Humidity
# count       5999.000000               5999.000000  5999.000000  \
# ...

# %%
df.isna().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %% [markdown]
# ## DATA CLEANING

# %%
df.rename(columns={"Formatted Date" : "formatted_Date",
                  "Summary" : "summary",
                  "Precip Type"  : "precip_Type",
                  "Temperature (C)" : "temperature(C)",
                  "Apparent Temperature (C)" : "Apparent_Temperature(C)",
                  "Humidity" : "humidity",
                  "Wind Speed (km/h)" : "wind_Speed(km/h)",
                  "Wind Bearing (degrees)": "wind_Bearing(degrees)",
                  "Visibility (km)" : "visibility(km)",
                  "Loud Cover" : "loud_Cover",
                  "Pressure (millibars)" : "pressure(millibars)"}, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5999 entries, 0 to 5998
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   formatted_Date           5999 non-null   object
#  1   summary                  5999 non-null   object
#  2   precip_Type              5999 non-null   object
#  3   temperature(C)           5999 non-null   float64
#  4   Apparent_Temperature(C)  5999 non-null   float64
#  5   humidity                 5999 non-null   float64
#  6   wind_Speed(km/h)         5999 non-null   float64
#  7   wind_Bearing(degrees)    5999 non-null   int64
#  8   visibility(km)           5999 non-null   float64
#  9   loud_Cover               5999 non-null   int64
#  10  pressure(millibars)      5999 non-null   float64
#  11  Daily Summary            5999 non-null   object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 562.5+ KB

# %%
cols = ['precip_Type','Daily Summary','wind_Bearing(degrees)','visibility(km)','loud_Cover']
df = df.drop(cols,axis=1)

# %%
# Converting Formatted Date from Object to DateTimeObject.
df["formatted_Date"] = pd.to_datetime(df["formatted_Date"], utc=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5999 entries, 0 to 5998
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   formatted_Date           5999 non-null   datetime64[ns, UTC]
#  1   summary                  5999 non-null   object
#  2   temperature(C)           5999 non-null   float64
#  3   Apparent_Temperature(C)  5999 non-null   float64
#  4   humidity                 5999 non-null   float64
#  5   wind_Speed(km/h)         5999 non-null   float64
#  6   pressure(millibars)      5999 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(5), object(1)
# memory usage: 328.2+ KB

# %%
# Indexing according to date and time.
df = df.sort_values(by="formatted_Date")

# %%
df = df.set_index("formatted_Date")

# %%
df.head()
# Out:
#                                  summary  temperature(C)
# formatted_Date
# 2005-12-31 23:00:00+00:00  Partly Cloudy        0.577778  \
# 2006-01-01 00:00:00+00:00  Mostly Cloudy        1.161111
# 2006-01-01 01:00:00+00:00  Mostly Cloudy        1.666667
# 2006-01-01 02:00:00+00:00       Overcast        1.711111
# 2006-01-01 03:00:00+00:00  Mostly Cloudy        1.183333
#
#                            Apparent_Temperature(C)  humidity
# formatted_Date
# 2005-12-31 23:00:00+00:00                -4.050000      0.89  \
# 2006-01-01 00:00:00+00:00                -3.238889      0.85
# 2006-01-01 01:00:00+00:00                -3.155556      0.82
# 2006-01-01 02:00:00+00:00                -2.194444      0.82
# 2006-01-01 03:00:00+00:00                -2.744444      0.86
#
#                            wind_Speed(km/h)  pressure(millibars)
# formatted_Date
# 2005-12-31 23:00:00+00:00           17.1143              1016.66
# 2006-01-01 00:00:00+00:00           16.6152              1016.15
# ...

# %%
#removing duplicate values in the index
df.index.drop_duplicates(keep='first')
# Out:
# DatetimeIndex(['2005-12-31 23:00:00+00:00', '2006-01-01 00:00:00+00:00',
#                '2006-01-01 01:00:00+00:00', '2006-01-01 02:00:00+00:00',
#                '2006-01-01 03:00:00+00:00', '2006-01-01 04:00:00+00:00',
#                '2006-01-01 05:00:00+00:00', '2006-01-01 06:00:00+00:00',
#                '2006-01-01 07:00:00+00:00', '2006-01-01 08:00:00+00:00',
#                ...
#                '2006-12-31 13:00:00+00:00', '2006-12-31 14:00:00+00:00',
#                '2006-12-31 15:00:00+00:00', '2006-12-31 16:00:00+00:00',
#                '2006-12-31 17:00:00+00:00', '2006-12-31 18:00:00+00:00',
#                '2006-12-31 19:00:00+00:00', '2006-12-31 20:00:00+00:00',
#                '2006-12-31 21:00:00+00:00', '2006-12-31 22:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='formatted_Date', length=5999, freq=None)

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %%
df.plot(y = "temperature(C)", figsize = (20,10), fontsize =20);

# %%
jan2006 = df['2006-01-01' : '2006-01-31']
jan2006
# Out:
#                                  summary  temperature(C)
# formatted_Date
# 2006-01-01 00:00:00+00:00  Mostly Cloudy        1.161111  \
# 2006-01-01 01:00:00+00:00  Mostly Cloudy        1.666667
# 2006-01-01 02:00:00+00:00       Overcast        1.711111
# 2006-01-01 03:00:00+00:00  Mostly Cloudy        1.183333
# 2006-01-01 04:00:00+00:00  Mostly Cloudy        1.205556
# ...                                  ...             ...
# 2006-01-31 19:00:00+00:00       Overcast       -2.400000
# 2006-01-31 20:00:00+00:00       Overcast       -1.933333
# 2006-01-31 21:00:00+00:00       Overcast       -1.922222
# 2006-01-31 22:00:00+00:00       Overcast       -2.077778
# 2006-01-31 23:00:00+00:00       Overcast       -2.144444
#
#                            Apparent_Temperature(C)  humidity
# formatted_Date
# 2006-01-01 00:00:00+00:00                -3.238889      0.85  \
# 2006-01-01 01:00:00+00:00                -3.155556      0.82
# ...

# %%
df.columns
# Out:
# Index(['summary', 'temperature(C)', 'Apparent_Temperature(C)', 'humidity',
#        'wind_Speed(km/h)', 'pressure(millibars)'],
#       dtype='object')

# %%
jan2006.plot(y = ['Apparent_Temperature(C)', 'temperature(C)'], kind = 'line', figsize = (20,10), fontsize =20);

# %%
winter = df['2006-01-01':'2006-02-28']
winter2 = df['2006-12-01':'2006-12-31']
spring = df['2006-03-01':'2006-05-31']
summer = df['2006-06-01':'2006-08-31']

# %%
winter.plot(y = ['Apparent_Temperature(C)', 'temperature(C)'], figsize = (20,10), fontsize =20);
winter2.plot(y = ['Apparent_Temperature(C)', 'temperature(C)'],  figsize = (20,10), fontsize =20);

# %%
spring.plot(y = ['Apparent_Temperature(C)', 'temperature(C)'],  figsize = (20,10), fontsize =20);

# %%
summer.plot(y = ['Apparent_Temperature(C)', 'temperature(C)'],  figsize = (20,10), fontsize =20);

# %% [markdown]
# ## Correlation in data

# %%
df.head().T
# Out:
# formatted_Date          2005-12-31 23:00:00+00:00 2006-01-01 00:00:00+00:00
# summary                             Partly Cloudy             Mostly Cloudy  \
# temperature(C)                           0.577778                  1.161111
# Apparent_Temperature(C)                     -4.05                 -3.238889
# humidity                                     0.89                      0.85
# wind_Speed(km/h)                          17.1143                   16.6152
# pressure(millibars)                       1016.66                   1016.15
#
# formatted_Date          2006-01-01 01:00:00+00:00 2006-01-01 02:00:00+00:00
# summary                             Mostly Cloudy                  Overcast  \
# temperature(C)                           1.666667                  1.711111
# Apparent_Temperature(C)                 -3.155556                 -2.194444
# humidity                                     0.82                      0.82
# ...

# %%
df['summary']=df['summary'].astype('category').cat.codes
df.corr(numeric_only = False)
# Out:
#                           summary  temperature(C)  Apparent_Temperature(C)
# summary                  1.000000        0.252380                 0.246659  \
# temperature(C)           0.252380        1.000000                 0.992881
# Apparent_Temperature(C)  0.246659        0.992881                 1.000000
# humidity                -0.257376       -0.564260                -0.535399
# wind_Speed(km/h)         0.030118       -0.053935                -0.126701
# pressure(millibars)      0.064788       -0.080315                -0.077491
#
#                          humidity  wind_Speed(km/h)  pressure(millibars)
# summary                 -0.257376          0.030118             0.064788
# temperature(C)          -0.564260         -0.053935            -0.080315
# Apparent_Temperature(C) -0.535399         -0.126701            -0.077491
# humidity                 1.000000         -0.209529             0.061836
# wind_Speed(km/h)        -0.209529          1.000000            -0.043172
# ...

# %%
#plotting the correlation
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(method="pearson"), annot = True)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5999 entries, 2005-12-31 23:00:00+00:00 to 2006-12-31 22:00:00+00:00
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   summary                  5999 non-null   int8
#  1   temperature(C)           5999 non-null   float64
#  2   Apparent_Temperature(C)  5999 non-null   float64
#  3   humidity                 5999 non-null   float64
#  4   wind_Speed(km/h)         5999 non-null   float64
#  5   pressure(millibars)      5999 non-null   float64
# dtypes: float64(5), int8(1)
# memory usage: 416.1 KB

# %% [markdown]
# ## Data Visualization

# %%
df.plot('temperature(C)', 'Apparent_Temperature(C)',kind="scatter")
# Out:
# <AxesSubplot:xlabel='temperature(C)', ylabel='Apparent_Temperature(C)'>

# %%
df.plot('humidity', 'temperature(C)',kind="scatter");

# %%
df.plot('temperature(C)','pressure(millibars)',kind="scatter");

# %%
df.plot('temperature(C)','wind_Speed(km/h)',kind="scatter");

# %%
sns.jointplot(kind='hex',y=df['humidity'],x=df['Apparent_Temperature(C)']);

# %%
plt.figure(figsize = (20,20))
sns.pairplot(df);
plt.show()

# %%
X = df.drop('Apparent_Temperature(C)', axis = 1)
y = df["Apparent_Temperature(C)"]

# %%
from sklearn.model_selection import train_test_split

np.random.seed(42)
X_train ,X_test, y_train ,y_test = train_test_split(X,y, test_size = 0.2)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((4799, 5), (4799,), (1200, 5), (1200,))

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([-0.04970814, 13.20606683, 16.47509663, ..., 14.14952789,
#        14.4809918 , 10.60935919])

# %%
regressor.score(X_test,y_test)
# Out:
# 0.9907712420437583

# %% [markdown]
# ### The Actual Apparent Temperature VS The predicted Apparent Temperature

# %%
data = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
data
# Out:
#                               Actual  Predicted
# formatted_Date
# 2006-01-04 11:00:00+00:00  -1.111111  -0.049708
# 2006-04-11 08:00:00+00:00  13.838889  13.206067
# 2006-08-21 04:00:00+00:00  17.177778  16.475097
# 2006-01-15 09:00:00+00:00  -6.300000  -5.138020
# 2006-01-04 06:00:00+00:00   2.138889   0.880268
# ...                              ...        ...
# 2006-07-22 01:00:00+00:00  20.444444  21.351920
# 2006-08-17 04:00:00+00:00  16.094444  15.647112
# 2006-05-13 20:00:00+00:00  15.050000  14.149528
# 2006-08-26 00:00:00+00:00  15.094444  14.480992
# 2006-06-04 21:00:00+00:00  11.188889  10.609359
#
# [1200 rows x 2 columns]

# %% [markdown]
# ### Calculating the error in prediction

# %%
from sklearn import metrics
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error:  0.9102851057561259
# Mean Squared Error:  1.3097853226844547
# Root Mean Squared Error:  1.1444585281627528

# %%
from xgboost import XGBRegressor

# %%
xgb=XGBRegressor(gamma=0.0453032172664104,
 learning_rate= 0.2155158027999262,
 max_depth= 5,
 n_estimators= 102,
 subsample= 0.9439761626945282)

# %%
xgb.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.0453032172664104, gpu_id=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.2155158027999262, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=102, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
y_pred = xgb.predict(X_test)

# %%
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error:  0.10545653897948287
# Mean Squared Error:  0.028160736428748324
# Root Mean Squared Error:  0.16781160993431987
